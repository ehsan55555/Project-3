# %%
import csv_to_sqlite

# %%
options = csv_to_sqlite.CsvOptions(typing_style="full")#, encoding="windows-1250") 
input_files = ["Resources/Motor_Vehicle_Collisions_-_Crashes.csv"] # pass in a list of CSV files
csv_to_sqlite.write_csv(input_files, "accidents.sqlite", options)
# Out:
# Written 223439 rows into 1 tables in 3.702 seconds
# 223439

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///accidents.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(autoload_with=engine)

# %%
Base.classes.keys()
# Out:
# []

# %%
import sqlite3
con = sqlite3.connect("accidents.sqlite")
cur = con.cursor()
cur.execute("SELECT * FROM 'Motor_Vehicle_Collisions_-_Crashes' LIMIT 0,30").fetchall()
# Out:
# [('1/1/2020',
#   '13:39',
#   'BROOKLYN',
#   '11204',
#   '',
#   '',
#   '',
#   'bay ridge pkwy                  ',
#   '18 avenue',
#   '',
#   '0',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   'Passing Too Closely',
#   '',
#   '',
#   '',
#   '',
#   4267649,
#   'Box Truck',
#   '',
#   '',
#   '',
#   ''),
#  ('1/1/2020',
#   '4:20',
#   '',
#   '',
#   '40.762196',
#   '-73.870415',
#   '(40.762196, -73.870415)',
#   '99 STREET                       ',
#   '',
#   '',
#   '1',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1,
#   0,
#   'Alcohol Involvement',
#   'Other Vehicular',
#   'Other Vehicular',
#   'Other Vehicular',
#   '',
#   4269445,
#   'Station Wagon/Sport Utility Vehicle',
#   'Station Wagon/Sport Utility Vehicle',
#   'Sedan',
#   'Station Wagon/Sport Utility Vehicle',
#   ''),
#  ('1/1/2020',
#   '15:41',
#   '',
#   '',
#   '40.780754',
#   '-73.95258',
#   '(40.780754, -73.95258)',
#   '3 AVENUE                        ',
#   '',
#   '',
#   '0',
#   0,
# ...
